# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

pd.set_option('display.max_columns',5000)
pd.set_option('display.max_rows',5000)
df = pd.read_csv('Data/df_bp7.csv')
df.shape
# Out:
# /tmp/ipykernel_112109/923887729.py:8: DtypeWarning: Columns (13,14,15,19,85,87,159,198) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('Data/df_bp7.csv')
# (96250, 611)

# %% [markdown]
# # Hiccups
#
# - When aggregating pitcher's past performance, we use default values to "smooth out" players with little / no history
# - With batters, this is more complicated, as different positions have different "typical" hitting capabilities
# - (Separate issue: should we be using training data with pitchers hitting?!?!)

# %%
def roll_column(df, col, winsize):
    # do the standard Pandas rolling calc
    t_col = df[col].rolling(winsize, closed='left').sum().to_numpy()
    
    # for the early columns, just do a rolling sum from the beginning
    t_col[:winsize] = np.concatenate(([0],df[col].iloc[:(winsize)].cumsum().to_numpy()[:-1]))

    return(t_col)

# %%
## Set up position level defaults
dd = {}
dd_p = {'batavg': .100, 'obp': .150, 'slg': .180, 'slgmod': .220, 'obs': .330, 'sobat': .3}
dd_ss_c = {'batavg': .205, 'obp': .260, 'slg': .300, 'slgmod': .320, 'obs': .540, 'sobat': .25}
dd_2b_3b = {'batavg': .240, 'obp': .280, 'slg': .350, 'slgmod': .355, 'obs': .630, 'sobat': .2}
dd_rest = {'batavg': .255, 'obp': .310, 'slg': .380, 'slgmod': .430, 'obs': .690, 'sobat': .2}
dd['p'] = dd_p
dd['ss'] = dd_ss_c
dd['c'] = dd_ss_c
dd['2b'] = dd_2b_3b
dd['3b'] = dd_2b_3b
dd['1b'] = dd_rest
dd['lf'] = dd_rest
dd['rf'] = dd_rest
dd['cf'] = dd_rest
dd['ph'] = dd_rest
dd['pr'] = dd_ss_c
dd['dh'] = dd_rest

# %%
def process_batter_df(p_id, dict_def):
    fname = 'RS-Batters/batting_data_'+p_id+'.csv'
    try:
        batter_df = pd.read_csv(fname)
        pos = batter_df.Pos.mode()[0]
        
        # corner cases where the most common position was a pair
        if ',' in pos:
            pos = pos.split(',')[0]
            
        batter_df['Date'] = (pd.to_datetime(batter_df.Date, format="%m-%d-%Y").astype(str).str.replace('-','')).astype(int)
        t_col = batter_df['dblhead_num'].copy()
        t_col[np.isnan(t_col)] = 0
        batter_df['dblheader_int'] = t_col.astype(int)
        for winsize in [30,75,162,350]:
            suff = str(winsize)
            for raw_col in ['AB','BB','H','2B','3B','HR','HBP','SO','SB','CS']:
                new_col = 'rollsum_'+raw_col+'_'+suff
                batter_df[new_col] = roll_column(batter_df, raw_col, winsize)

            ab_per_game_def = 2
            pa_per_game_def = 2
            batavg_def = dict_def[pos]['batavg']
            obp_def = dict_def[pos]['obp']
            slg_def = dict_def[pos]['slg']
            slgmod_def = dict_def[pos]['slgmod']
            so_bat_perc_def = dict_def[pos]['sobat']

            # Columns created by aggregation above
            ab_col = 'rollsum_AB_'+str(winsize)
            h_col = 'rollsum_H_'+str(winsize)
            bb_col = 'rollsum_BB_'+str(winsize)
            hbp_col = 'rollsum_HBP_'+str(winsize)
            doub_col = 'rollsum_2B_'+str(winsize)
            trip_col = 'rollsum_3B_'+str(winsize)
            hr_col = 'rollsum_HR_'+str(winsize)
            so_col = 'rollsum_SO_'+str(winsize)

            # Columns I will define below
            abmod_col = 'ABmod_'+str(winsize)
            fakeab_col = 'fakeAB_'+str(winsize)
            pa_col = 'PA_'+str(winsize)
            pamod_col = 'PAmod_'+str(winsize)
            fakepa_col = 'fakePA_'+str(winsize)
            xb_col = 'XB_'+str(winsize) # represents extra bases beyond hits
            slg_col = 'SLG_'+str(winsize)
            slgmod_col = 'SLGmod_'+str(winsize)
            batavg_col = 'BATAVG_'+str(winsize)
            so_bat_perc_col = 'SObat_perc_'+str(winsize)
            obp_col = 'OBP_'+str(winsize)
            obs_col = 'OBS_'+str(winsize)

            # calculate BATAVG, with smoothing for low AB numbers
            batter_df[abmod_col] = np.maximum(batter_df[ab_col],winsize*ab_per_game_def)
            batter_df[fakeab_col] = np.minimum(batter_df[abmod_col]-batter_df[ab_col],0)
            batter_df[batavg_col] = (batter_df[h_col] + (batter_df[fakeab_col]*batavg_def))/(batter_df[abmod_col])

            # calculate SLG, with smoothing for low AB numbers
            batter_df[xb_col] = batter_df[doub_col] + 2*batter_df[trip_col] + 3*batter_df[hr_col]
            batter_df[slg_col] = (batter_df[h_col] + batter_df[xb_col] + 
                                     (batter_df[fakeab_col]*slg_def))/(batter_df[abmod_col])

            # calculate OBP, with smoothing for low PA numbers
            batter_df[pa_col] = batter_df[ab_col]+batter_df[bb_col]+batter_df[hbp_col]
            batter_df[pamod_col] = np.maximum(batter_df[pa_col],winsize*pa_per_game_def)
            batter_df[fakepa_col] = np.minimum(batter_df[pamod_col]-batter_df[pa_col],0)
            batter_df[obp_col] = (batter_df[h_col] + batter_df[bb_col] + batter_df[hbp_col]
                                  + (batter_df[fakepa_col]*obp_def))/(
                                    batter_df[pamod_col])

            # calculate SLGmod, with smoothing for low PA numbers
            batter_df[slgmod_col] = (batter_df[so_col] + batter_df[bb_col] + batter_df[hbp_col] 
                                     +batter_df[xb_col] + (batter_df[fakepa_col]*slgmod_def))/(
                                    batter_df[pamod_col])

            # calculate SObat_perc, with smoothing for low PA numbers
            batter_df[so_bat_perc_col] = (batter_df[so_col] + (batter_df[fakepa_col]*so_bat_perc_def))/(
                                    batter_df[pamod_col])

            # calculate OBS
            batter_df[obs_col] = batter_df[obp_col]+batter_df[slg_col]


            batter_df['date_dblhead'] = (batter_df['Date'].astype(str) + batter_df['dblheader_int'].astype(str)).astype(int)
            batter_df.set_index('date_dblhead', inplace=True)
    except:
        try:
            print(f'issue for {fname} at position {pos}, returning None')
        except:
            print(f'issue for {fname}, returning None')
        batter_df = None
    return(batter_df)

# %%
batter_ids = np.array([])
for num in range(1,10):
    for suffix in ['_h','_v']:
        # Check whether this should be '_id' or '_name'
        colname = 'batter'+str(num)+'_name'+suffix
        batter_ids = np.concatenate((batter_ids, pd.unique(df[colname])))
batter_ids = np.unique(batter_ids)

# %%
## Create a batter data dictionary from the saved batter files
batter_data_dict = {}
for i,b_id in enumerate(batter_ids):
    if i%100==0:
        print(i)
    batter_data_dict[b_id] = process_batter_df(b_id, dd)
# Out:
# 0
# 100
# 200
# issue for RS-Batters/batting_data_baezm001.csv, returning None
# 300
# issue for RS-Batters/batting_data_bedrc001.csv, returning None
# 400
# 500
# 600
# issue for RS-Batters/batting_data_boshb001.csv, returning None
# issue for RS-Batters/batting_data_brogc001.csv, returning None
# 700
# 800
# 900
# issue for RS-Batters/batting_data_castm002.csv, returning None
# 1000
# issue for RS-Batters/batting_data_claua001.csv, returning None
# 1100
# issue for RS-Batters/batting_data_colet001.csv, returning None
# issue for RS-Batters/batting_data_contr001.csv, returning None
# 1200
# 1300
# 1400
# 1500
# 1600
# 1700
# 1800
# 1900
# issue for RS-Batters/batting_data_garcf003.csv, returning None
# 2000
# issue for RS-Batters/batting_data_gelts001.csv, returning None
# 2100
# issue for RS-Batters/batting_data_gonzv001.csv, returning None
# 2200
# issue for RS-Batters/batting_data_greec004.csv, returning None
# 2300
# 2400
# 2500
# 2600
# 2700
# 2800
# 2900
# issue for RS-Batters/batting_data_karpr001.csv, returning None
# 3000
# 3100
# 3200
# 3300
# 3400
# 3500
# 3600
# 3700
# 3800
# issue for RS-Batters/batting_data_middk001.csv, returning None
# 3900
# 4000
# 4100
# 4200
# issue for RS-Batters/batting_data_nuned002.csv, returning None
# issue for RS-Batters/batting_data_oconj001.csv, returning None
# 4300
# issue for RS-Batters/batting_data_oviel001.csv, returning None
# 4400
# 4500
# 4600
# 4700
# issue for RS-Batters/batting_data_quirr001.csv, returning None
# issue for RS-Batters/batting_data_ramin002.csv, returning None
# 4800
# 4900
# 5000
# issue for RS-Batters/batting_data_rosar001.csv, returning None
# 5100
# issue for RS-Batters/batting_data_sadzc001.csv, returning None
# issue for RS-Batters/batting_data_sancc002.csv, returning None
# 5200
# 5300
# 5400
# 5500
# issue for RS-Batters/batting_data_stanr002.csv, returning None
# 5600
# 5700
# issue for RS-Batters/batting_data_thomb001.csv, returning None
# 5800
# 5900
# 6000
# issue for RS-Batters/batting_data_vitkj001.csv, returning None
# 6100
# 6200
# 6300
# issue for RS-Batters/batting_data_wingt001.csv, returning None
# 6400

# %%
new_col_dict = {}
colstems = ['BATAVG', 'OBP', 'SLG', 'OBS', 'SLGmod','SObat_perc']
winsizes = [30,75,162,350]
new_col_list = [stem+'_'+str(winsize)+'_b'+str(i)+hv   for stem in colstems for winsize in winsizes 
                for i in range(1,10) for hv in ['_h','_v']]
for col in new_col_list:
    new_col_dict[col] = np.empty(df.shape[0])
    new_col_dict[col].fill(np.nan)

# %%
def get_batter_ids_from_row(row):
    b_cols = ['batter1_name_h', 'batter1_name_v', 'batter2_name_h',
       'batter2_name_v', 'batter3_name_h', 'batter3_name_v',
       'batter4_name_h', 'batter4_name_v', 'batter5_name_h',
       'batter5_name_v', 'batter6_name_h', 'batter6_name_v',
       'batter7_name_h', 'batter7_name_v', 'batter8_name_h',
       'batter8_name_v', 'batter9_name_h', 'batter9_name_v']
    return(row.loc[b_cols].to_dict())

# %%
## Add in all the statistics about the starting lineup batters
for i in range(df.shape[0]):
    row = df.iloc[i,:]
    if i%1000==0:
        print(i)
    bid_dict = get_batter_ids_from_row(row)
    date_dblhead = row['date_dblhead']
    for hv in ['_h','_v']:
        for j in range(1,10):
            # Again, check if should be name or id col
            #curr_col = 'batter'+str(j)+'_id'+hv
            curr_col = 'batter'+str(j)+'_name'+hv
            curr_b_id = bid_dict[curr_col]
            if curr_b_id in batter_data_dict.keys():
                curr_batter_df = batter_data_dict[curr_b_id]
                if (curr_batter_df is not None) and (curr_batter_df.shape[0]>0):
                    try:
                        curr_batter_row = curr_batter_df.loc[date_dblhead,:]
                    except:
                        print(f'date not found for batter {curr_b_id} game {date_dblhead}')
                        prev_game_indices = np.where(curr_batter_df.index<date_dblhead)[0]
                        if len(prev_game_indices)==0:
                            index_to_use = 0
                        else:
                            index_to_use = np.max(prev_game_indices)
                        curr_batter_row = curr_batter_df.iloc[index_to_use,:]
                        print(f'using date {curr_batter_df.index[index_to_use]}')
                    if (curr_batter_row.ndim>1):
                        curr_batter_row = curr_batter_row.iloc[0,:]
                    for stem in colstems:
                        for winsize in winsizes:
                            newcolname = stem+'_'+str(winsize)+'_b'+str(j)+hv
                            new_col_dict[newcolname][i] = curr_batter_row[stem+'_'+str(winsize)]
                else:
                    print(f'No data found for {curr_b_id}')
            else:
                print(f'batter not found for {curr_b_id}')
# Out:
# 0
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# date not found for batter schud001 game 198405260
# using date 198310010
# 9000
# 10000
# No data found for oconj001
# 11000
# 12000
# 13000
# date not found for batter smitm001 game 198609200
# using date 198404220
# 14000
# date not found for batter penah001 game 198610050
# using date 198704290
# 15000
# date not found for batter lea-c001 game 198709160
# using date 198409160
# 16000
# date not found for batter mallr001 game 198710020
# using date 199108170
# 17000
# date not found for batter krueb001 game 198807040
# using date 199209050
# 18000
# 19000
# 20000
# 21000
# 22000
# 23000
# 24000
# 25000
# 26000
# No data found for vitkj001
# 27000
# 28000
# 29000
# 30000
# 31000
# 32000
# date not found for batter barbb002 game 199604140
# using date 199510010
# 33000
# No data found for quirr001
# 34000
# date not found for batter cormr001 game 199704050
# using date 199609270
# 35000
# 36000
# No data found for karpr001
# 37000
# date not found for batter myerr002 game 199709270
# using date 199609272
# 38000
# 39000
# date not found for batter ojalk001 game 199904180
# using date 199809272
# 40000
# date not found for batter fyhrm001 game 199907110
# using date 200104020
# 41000
# date not found for batter tejem001 game 199909080
# using date 200204030
# 42000
# date not found for batter rigdp001 game 200006070
# using date 200007290
# 43000
# date not found for batter beltr001 game 200007171
# using date 199910020
# 44000
# 45000
# No data found for thomb001
# date not found for batter loewc001 game 200106160
# using date 199909290
# 46000
# date not found for batter boroj001 game 200108110
# using date 199609290
# 47000
# 48000
# 49000
# date not found for batter tankd001 game 200304090
# using date 200209280
# 50000
# date not found for batter daalo001 game 200306050
# using date 200209270
# date not found for batter biern001 game 200306060
# using date 200107230
# No data found for rosar001
# 51000
# date not found for batter fernj002 game 200404120
# using date 200309260
# 52000
# date not found for batter reyns001 game 200406280
# using date 200309270
# date not found for batter tejem001 game 200407010
# using date 200309280
# 53000
# 54000
# 55000
# 56000
# date not found for batter rasnd001 game 200509060
# using date 200805040
# 57000
# 58000
# 59000
# date not found for batter rasnd001 game 200705190
# using date 200805040
# 60000
# 61000
# 62000
# date not found for batter albem001 game 200806250
# using date 200709280
# date not found for batter muldm001 game 200807090
# using date 200709160
# 63000
# date not found for batter guzma001 game 200809280
# using date 200706010
# 64000
# 65000
# date not found for batter chacj001 game 200908110
# using date 201004270
# 66000
# date not found for batter jakuc001 game 201004240
# using date 200909250
# date not found for batter eveld001 game 201005220
# using date 200809240
# 67000
# 68000
# 69000
# 70000
# 71000
# date not found for batter marqj001 game 201205200
# using date 201108140
# 72000
# date not found for batter valdr002 game 201206270
# using date 201010020
# 73000
# 74000
# 75000
# 76000
# 77000
# date not found for batter hendl001 game 201406200
# using date 201209300
# 78000
# No data found for gelts001
# 79000
# No data found for gelts001
# date not found for batter garcy001 game 201507060
# using date 201409280
# date not found for batter gravk001 game 201507260
# using date 201604070
# 80000
# date not found for batter gonzm005 game 201509010
# using date 201409280
# No data found for garcf003
# 81000
# 82000
# date not found for batter mayem001 game 201607240
# using date 201803290
# date not found for batter matub001 game 201607310
# using date 201210020
# 83000
# date not found for batter gilms001 game 201609240
# using date 201510010
# date not found for batter guthj001 game 201704080
# using date 201509260
# 84000
# date not found for batter skoge001 game 201706090
# using date 201804100
# 85000
# 86000
# date not found for batter tsenj001 game 201805080
# using date 201709280
# date not found for batter fulmc001 game 201805110
# using date 201904080
# date not found for batter ventj001 game 201806060
# using date 201010030
# date not found for batter andrm001 game 201807040
# using date 201609300
# No data found for stanr002
# date not found for batter flexc001 game 201807080
# using date 201710010
# 87000
# No data found for stanr002
# date not found for batter garcj004 game 201809081
# using date 201808200
# No data found for sadzc001
# No data found for claua001
# 88000
# No data found for stanr002
# date not found for batter barnj002 game 201905010
# using date 201709300
# No data found for stanr002
# date not found for batter felim001 game 201905240
# using date 201809300
# date not found for batter alvaj003 game 201906010
# using date 201610010
# No data found for bedrc001
# 89000
# No data found for ramin002
# No data found for colet001
# No data found for colet001
# No data found for boshb001
# date not found for batter fontw001 game 201908210
# using date 201907070
# 90000
# No data found for wingt001
# date not found for batter fontw001 game 201909030
# using date 201907070
# date not found for batter gausk001 game 201909160
# using date 201908020
# date not found for batter snelb001 game 201909170
# using date 201809290
# date not found for batter walkt004 game 201909290
# using date 201804140
# No data found for baezm001
# 91000
# No data found for castm002
# 92000
# No data found for castm002
# date not found for batter haled001 game 202105200
# using date 201510010
# date not found for batter menec001 game 202106122
# using date 201909270
# No data found for gonzv001
# date not found for batter reedj005 game 202107070
# using date 202108150
# date not found for batter bassa001 game 202107090
# using date 201309190
# date not found for batter loupa001 game 202107110
# using date 201210020
# No data found for nuned002
# No data found for middk001
# date not found for batter loupa001 game 202107262
# using date 201210020
# No data found for oviel001
# No data found for sancc002
# 93000
# No data found for brogc001
# date not found for batter stram001 game 202108170
# using date 201909290
# date not found for batter johnp001 game 202108240
# using date 201809300
# date not found for batter leond003 game 202109050
# using date 201809280
# date not found for batter howas003 game 202109070
# using date 202107260
# date not found for batter mayem001 game 202109080
# using date 201909270
# date not found for batter leond003 game 202109100
# using date 201809280
# date not found for batter leond003 game 202109130
# using date 201809280
# date not found for batter leond003 game 202109150
# using date 201809280
# No data found for bedrc001
# date not found for batter johnp001 game 202109160
# using date 201809300
# No data found for greec004
# date not found for batter howas002 game 202109240
# using date 201909290
# date not found for batter syndn001 game 202109282
# using date 201909290
# No data found for contr001
# date not found for batter syndn001 game 202110030
# using date 201909290
# 94000
# 95000
# 96000

# %%
for key, val in new_col_dict.items():
    df[key] = val
# Out:
# /tmp/ipykernel_112109/606030580.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[key] = val
# /tmp/ipykernel_112109/606030580.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[key] = val
# /tmp/ipykernel_112109/606030580.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[key] = val
# /tmp/ipykernel_112109/606030580.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[key] = val
# /tmp/ipykernel_112109/606030580.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[key] = val
# /tmp/ipykernel_112109/606030580.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[key] = val
# /tmp/ipykernel_112109/606030580.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[key] = val
# /tmp/ipykernel_112109/606030580.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[key] = val
# /tmp/ipykernel_112109/606030580.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[key] = val
# /tmp/ipykernel_112109/606030580.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[key] = val
# /tmp/ipykernel_112109/606030580.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[key] = val
# /tmp/ipykernel_112109/606030580.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[key] = val
# /tmp/ipykernel_112109/606030580.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[key] = val
# /tmp/ipykernel_112109/606030580.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[key] = val
# /tmp/ipykernel_112109/606030580.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[key] = val
# /tmp/ipykernel_112109/606030580.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[key] = val
# /tmp/ipykernel_112109/606030580.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[key] = val
# /tmp/ipykernel_112109/606030580.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[key] = val
# /tmp/ipykernel_112109/606030580.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[key] = val
# /tmp/ipykernel_112109/606030580.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[key] = val
# /tmp/ipykernel_112109/606030580.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[key] = val
# /tmp/ipykernel_112109/606030580.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[key] = val
# /tmp/ipykernel_112109/606030580.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[key] = val
# /tmp/ipykernel_112109/606030580.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[key] = val
# /tmp/ipykernel_112109/606030580.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[key] = val
# /tmp/ipykernel_112109/606030580.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[key] = val
# /tmp/ipykernel_112109/606030580.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[key] = val
# /tmp/ipykernel_112109/606030580.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[key] = val
# /tmp/ipykernel_112109/606030580.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[key] = val
# /tmp/ipykernel_112109/606030580.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[key] = val
# /tmp/ipykernel_112109/606030580.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[key] = val
# /tmp/ipykernel_112109/606030580.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[key] = val
# /tmp/ipykernel_112109/606030580.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[key] = val
# /tmp/ipykernel_112109/606030580.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[key] = val
# /tmp/ipykernel_112109/606030580.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[key] = val
# /tmp/ipykernel_112109/606030580.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[key] = val
# /tmp/ipykernel_112109/606030580.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[key] = val
# /tmp/ipykernel_112109/606030580.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[key] = val
# /tmp/ipykernel_112109/606030580.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[key] = val
# /tmp/ipykernel_112109/606030580.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[key] = val
# /tmp/ipykernel_112109/606030580.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[key] = val
# /tmp/ipykernel_112109/606030580.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[key] = val
# /tmp/ipykernel_112109/606030580.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[key] = val
# /tmp/ipykernel_112109/606030580.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[key] = val
# /tmp/ipykernel_112109/606030580.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[key] = val
# /tmp/ipykernel_112109/606030580.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[key] = val
# /tmp/ipykernel_112109/606030580.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[key] = val
# /tmp/ipykernel_112109/606030580.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[key] = val
# /tmp/ipykernel_112109/606030580.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[key] = val
# /tmp/ipykernel_112109/606030580.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[key] = val
# /tmp/ipykernel_112109/606030580.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[key] = val
# /tmp/ipykernel_112109/606030580.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[key] = val
# /tmp/ipykernel_112109/606030580.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[key] = val
# /tmp/ipykernel_112109/606030580.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[key] = val
# /tmp/ipykernel_112109/606030580.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[key] = val
# /tmp/ipykernel_112109/606030580.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[key] = val
# /tmp/ipykernel_112109/606030580.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[key] = val
# /tmp/ipykernel_112109/606030580.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[key] = val
# /tmp/ipykernel_112109/606030580.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[key] = val
# /tmp/ipykernel_112109/606030580.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[key] = val
# /tmp/ipykernel_112109/606030580.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[key] = val
# /tmp/ipykernel_112109/606030580.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[key] = val
# /tmp/ipykernel_112109/606030580.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[key] = val
# /tmp/ipykernel_112109/606030580.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[key] = val
# /tmp/ipykernel_112109/606030580.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[key] = val
# /tmp/ipykernel_112109/606030580.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[key] = val
# /tmp/ipykernel_112109/606030580.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[key] = val
# /tmp/ipykernel_112109/606030580.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[key] = val
# /tmp/ipykernel_112109/606030580.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[key] = val
# /tmp/ipykernel_112109/606030580.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[key] = val
# /tmp/ipykernel_112109/606030580.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[key] = val
# /tmp/ipykernel_112109/606030580.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[key] = val
# /tmp/ipykernel_112109/606030580.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[key] = val
# /tmp/ipykernel_112109/606030580.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[key] = val
# /tmp/ipykernel_112109/606030580.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[key] = val
# /tmp/ipykernel_112109/606030580.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[key] = val
# /tmp/ipykernel_112109/606030580.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[key] = val
# /tmp/ipykernel_112109/606030580.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[key] = val
# /tmp/ipykernel_112109/606030580.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[key] = val
# /tmp/ipykernel_112109/606030580.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[key] = val
# /tmp/ipykernel_112109/606030580.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[key] = val
# /tmp/ipykernel_112109/606030580.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[key] = val
# /tmp/ipykernel_112109/606030580.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[key] = val
# /tmp/ipykernel_112109/606030580.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[key] = val
# /tmp/ipykernel_112109/606030580.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[key] = val
# /tmp/ipykernel_112109/606030580.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[key] = val
# /tmp/ipykernel_112109/606030580.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[key] = val
# /tmp/ipykernel_112109/606030580.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[key] = val
# /tmp/ipykernel_112109/606030580.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[key] = val
# /tmp/ipykernel_112109/606030580.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[key] = val
# /tmp/ipykernel_112109/606030580.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[key] = val
# /tmp/ipykernel_112109/606030580.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[key] = val
# /tmp/ipykernel_112109/606030580.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[key] = val
# /tmp/ipykernel_112109/606030580.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[key] = val
# /tmp/ipykernel_112109/606030580.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[key] = val
# /tmp/ipykernel_112109/606030580.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[key] = val
# /tmp/ipykernel_112109/606030580.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[key] = val
# /tmp/ipykernel_112109/606030580.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[key] = val
# /tmp/ipykernel_112109/606030580.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[key] = val
# /tmp/ipykernel_112109/606030580.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[key] = val
# /tmp/ipykernel_112109/606030580.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[key] = val
# /tmp/ipykernel_112109/606030580.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[key] = val
# /tmp/ipykernel_112109/606030580.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[key] = val
# /tmp/ipykernel_112109/606030580.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[key] = val
# /tmp/ipykernel_112109/606030580.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[key] = val
# /tmp/ipykernel_112109/606030580.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[key] = val
# /tmp/ipykernel_112109/606030580.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[key] = val
# /tmp/ipykernel_112109/606030580.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[key] = val
# /tmp/ipykernel_112109/606030580.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[key] = val
# /tmp/ipykernel_112109/606030580.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[key] = val
# /tmp/ipykernel_112109/606030580.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[key] = val
# /tmp/ipykernel_112109/606030580.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[key] = val
# /tmp/ipykernel_112109/606030580.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[key] = val
# /tmp/ipykernel_112109/606030580.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[key] = val
# /tmp/ipykernel_112109/606030580.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[key] = val
# /tmp/ipykernel_112109/606030580.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[key] = val
# /tmp/ipykernel_112109/606030580.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[key] = val
# /tmp/ipykernel_112109/606030580.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[key] = val
# /tmp/ipykernel_112109/606030580.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[key] = val
# /tmp/ipykernel_112109/606030580.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[key] = val
# /tmp/ipykernel_112109/606030580.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[key] = val
# /tmp/ipykernel_112109/606030580.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[key] = val
# /tmp/ipykernel_112109/606030580.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[key] = val
# /tmp/ipykernel_112109/606030580.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[key] = val
# /tmp/ipykernel_112109/606030580.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[key] = val
# /tmp/ipykernel_112109/606030580.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[key] = val
# /tmp/ipykernel_112109/606030580.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[key] = val
# /tmp/ipykernel_112109/606030580.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[key] = val
# /tmp/ipykernel_112109/606030580.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[key] = val
# /tmp/ipykernel_112109/606030580.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[key] = val
# /tmp/ipykernel_112109/606030580.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[key] = val
# /tmp/ipykernel_112109/606030580.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[key] = val
# /tmp/ipykernel_112109/606030580.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[key] = val
# /tmp/ipykernel_112109/606030580.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[key] = val
# /tmp/ipykernel_112109/606030580.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[key] = val
# /tmp/ipykernel_112109/606030580.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[key] = val
# /tmp/ipykernel_112109/606030580.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[key] = val
# /tmp/ipykernel_112109/606030580.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[key] = val
# /tmp/ipykernel_112109/606030580.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[key] = val
# /tmp/ipykernel_112109/606030580.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[key] = val
# /tmp/ipykernel_112109/606030580.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[key] = val
# /tmp/ipykernel_112109/606030580.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[key] = val
# /tmp/ipykernel_112109/606030580.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[key] = val
# /tmp/ipykernel_112109/606030580.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[key] = val
# /tmp/ipykernel_112109/606030580.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[key] = val
# ...
#   df[key] = val
# /tmp/ipykernel_112109/606030580.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[key] = val
# /tmp/ipykernel_112109/606030580.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[key] = val
# /tmp/ipykernel_112109/606030580.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[key] = val
# /tmp/ipykernel_112109/606030580.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[key] = val
# /tmp/ipykernel_112109/606030580.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[key] = val
# /tmp/ipykernel_112109/606030580.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[key] = val
# /tmp/ipykernel_112109/606030580.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[key] = val
# /tmp/ipykernel_112109/606030580.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[key] = val
# /tmp/ipykernel_112109/606030580.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[key] = val
# /tmp/ipykernel_112109/606030580.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[key] = val
# /tmp/ipykernel_112109/606030580.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[key] = val
# /tmp/ipykernel_112109/606030580.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[key] = val
# /tmp/ipykernel_112109/606030580.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[key] = val
# /tmp/ipykernel_112109/606030580.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[key] = val
# /tmp/ipykernel_112109/606030580.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[key] = val
# /tmp/ipykernel_112109/606030580.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[key] = val
# /tmp/ipykernel_112109/606030580.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[key] = val
# /tmp/ipykernel_112109/606030580.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[key] = val
# /tmp/ipykernel_112109/606030580.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[key] = val
# /tmp/ipykernel_112109/606030580.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[key] = val
# /tmp/ipykernel_112109/606030580.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[key] = val
# /tmp/ipykernel_112109/606030580.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[key] = val
# /tmp/ipykernel_112109/606030580.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[key] = val
# /tmp/ipykernel_112109/606030580.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[key] = val
# /tmp/ipykernel_112109/606030580.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[key] = val
# /tmp/ipykernel_112109/606030580.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[key] = val
# /tmp/ipykernel_112109/606030580.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[key] = val
# /tmp/ipykernel_112109/606030580.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[key] = val
# /tmp/ipykernel_112109/606030580.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[key] = val
# /tmp/ipykernel_112109/606030580.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[key] = val
# /tmp/ipykernel_112109/606030580.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[key] = val
# /tmp/ipykernel_112109/606030580.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[key] = val
# /tmp/ipykernel_112109/606030580.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[key] = val
# /tmp/ipykernel_112109/606030580.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[key] = val
# /tmp/ipykernel_112109/606030580.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[key] = val
# /tmp/ipykernel_112109/606030580.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[key] = val
# /tmp/ipykernel_112109/606030580.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[key] = val
# /tmp/ipykernel_112109/606030580.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[key] = val
# /tmp/ipykernel_112109/606030580.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[key] = val
# /tmp/ipykernel_112109/606030580.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[key] = val
# /tmp/ipykernel_112109/606030580.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[key] = val
# /tmp/ipykernel_112109/606030580.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[key] = val
# /tmp/ipykernel_112109/606030580.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[key] = val
# /tmp/ipykernel_112109/606030580.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[key] = val
# /tmp/ipykernel_112109/606030580.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[key] = val
# /tmp/ipykernel_112109/606030580.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[key] = val
# /tmp/ipykernel_112109/606030580.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[key] = val
# /tmp/ipykernel_112109/606030580.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[key] = val

# %%
df = df.copy()
newcols = new_col_dict.keys()

# %%
df.loc[:,newcols].isnull().sum()
# Out:
# BATAVG_30_b1_h          0
# BATAVG_30_b1_v          0
# BATAVG_30_b2_h          0
# BATAVG_30_b2_v          0
# BATAVG_30_b3_h          0
# BATAVG_30_b3_v          0
# BATAVG_30_b4_h          0
# BATAVG_30_b4_v          0
# BATAVG_30_b5_h          0
# BATAVG_30_b5_v          0
# BATAVG_30_b6_h          0
# BATAVG_30_b6_v          0
# BATAVG_30_b7_h          0
# BATAVG_30_b7_v          0
# BATAVG_30_b8_h          0
# BATAVG_30_b8_v          1
# BATAVG_30_b9_h         10
# BATAVG_30_b9_v         22
# BATAVG_75_b1_h          0
# BATAVG_75_b1_v          0
# BATAVG_75_b2_h          0
# BATAVG_75_b2_v          0
# BATAVG_75_b3_h          0
# BATAVG_75_b3_v          0
# BATAVG_75_b4_h          0
# BATAVG_75_b4_v          0
# BATAVG_75_b5_h          0
# BATAVG_75_b5_v          0
# BATAVG_75_b6_h          0
# BATAVG_75_b6_v          0
# BATAVG_75_b7_h          0
# BATAVG_75_b7_v          0
# BATAVG_75_b8_h          0
# BATAVG_75_b8_v          1
# BATAVG_75_b9_h         10
# BATAVG_75_b9_v         22
# BATAVG_162_b1_h         0
# BATAVG_162_b1_v         0
# BATAVG_162_b2_h         0
# BATAVG_162_b2_v         0
# BATAVG_162_b3_h         0
# BATAVG_162_b3_v         0
# BATAVG_162_b4_h         0
# BATAVG_162_b4_v         0
# BATAVG_162_b5_h         0
# BATAVG_162_b5_v         0
# BATAVG_162_b6_h         0
# BATAVG_162_b6_v         0
# BATAVG_162_b7_h         0
# BATAVG_162_b7_v         0
# BATAVG_162_b8_h         0
# BATAVG_162_b8_v         1
# BATAVG_162_b9_h        10
# BATAVG_162_b9_v        22
# BATAVG_350_b1_h         0
# BATAVG_350_b1_v         0
# BATAVG_350_b2_h         0
# BATAVG_350_b2_v         0
# BATAVG_350_b3_h         0
# BATAVG_350_b3_v         0
# BATAVG_350_b4_h         0
# BATAVG_350_b4_v         0
# BATAVG_350_b5_h         0
# BATAVG_350_b5_v         0
# BATAVG_350_b6_h         0
# BATAVG_350_b6_v         0
# BATAVG_350_b7_h         0
# BATAVG_350_b7_v         0
# BATAVG_350_b8_h         0
# BATAVG_350_b8_v         1
# BATAVG_350_b9_h        10
# BATAVG_350_b9_v        22
# OBP_30_b1_h             0
# OBP_30_b1_v             0
# OBP_30_b2_h             0
# OBP_30_b2_v             0
# OBP_30_b3_h             0
# OBP_30_b3_v             0
# OBP_30_b4_h             0
# OBP_30_b4_v             0
# OBP_30_b5_h             0
# OBP_30_b5_v             0
# OBP_30_b6_h             0
# OBP_30_b6_v             0
# OBP_30_b7_h             0
# OBP_30_b7_v             0
# OBP_30_b8_h             0
# OBP_30_b8_v             1
# OBP_30_b9_h            10
# OBP_30_b9_v            22
# OBP_75_b1_h             0
# OBP_75_b1_v             0
# OBP_75_b2_h             0
# OBP_75_b2_v             0
# OBP_75_b3_h             0
# OBP_75_b3_v             0
# OBP_75_b4_h             0
# OBP_75_b4_v             0
# OBP_75_b5_h             0
# OBP_75_b5_v             0
# OBP_75_b6_h             0
# OBP_75_b6_v             0
# OBP_75_b7_h             0
# OBP_75_b7_v             0
# OBP_75_b8_h             0
# OBP_75_b8_v             1
# OBP_75_b9_h            10
# OBP_75_b9_v            22
# OBP_162_b1_h            0
# OBP_162_b1_v            0
# OBP_162_b2_h            0
# OBP_162_b2_v            0
# OBP_162_b3_h            0
# OBP_162_b3_v            0
# OBP_162_b4_h            0
# OBP_162_b4_v            0
# OBP_162_b5_h            0
# OBP_162_b5_v            0
# OBP_162_b6_h            0
# OBP_162_b6_v            0
# OBP_162_b7_h            0
# OBP_162_b7_v            0
# OBP_162_b8_h            0
# OBP_162_b8_v            1
# OBP_162_b9_h           10
# OBP_162_b9_v           22
# OBP_350_b1_h            0
# OBP_350_b1_v            0
# OBP_350_b2_h            0
# OBP_350_b2_v            0
# OBP_350_b3_h            0
# OBP_350_b3_v            0
# OBP_350_b4_h            0
# OBP_350_b4_v            0
# OBP_350_b5_h            0
# OBP_350_b5_v            0
# OBP_350_b6_h            0
# OBP_350_b6_v            0
# OBP_350_b7_h            0
# OBP_350_b7_v            0
# OBP_350_b8_h            0
# OBP_350_b8_v            1
# OBP_350_b9_h           10
# OBP_350_b9_v           22
# SLG_30_b1_h             0
# SLG_30_b1_v             0
# SLG_30_b2_h             0
# SLG_30_b2_v             0
# SLG_30_b3_h             0
# SLG_30_b3_v             0
# SLG_30_b4_h             0
# SLG_30_b4_v             0
# SLG_30_b5_h             0
# SLG_30_b5_v             0
# SLG_30_b6_h             0
# SLG_30_b6_v             0
# SLG_30_b7_h             0
# SLG_30_b7_v             0
# SLG_30_b8_h             0
# SLG_30_b8_v             1
# SLG_30_b9_h            10
# SLG_30_b9_v            22
# SLG_75_b1_h             0
# SLG_75_b1_v             0
# SLG_75_b2_h             0
# SLG_75_b2_v             0
# SLG_75_b3_h             0
# SLG_75_b3_v             0
# SLG_75_b4_h             0
# SLG_75_b4_v             0
# SLG_75_b5_h             0
# SLG_75_b5_v             0
# SLG_75_b6_h             0
# SLG_75_b6_v             0
# SLG_75_b7_h             0
# SLG_75_b7_v             0
# SLG_75_b8_h             0
# SLG_75_b8_v             1
# SLG_75_b9_h            10
# SLG_75_b9_v            22
# SLG_162_b1_h            0
# SLG_162_b1_v            0
# SLG_162_b2_h            0
# SLG_162_b2_v            0
# SLG_162_b3_h            0
# SLG_162_b3_v            0
# SLG_162_b4_h            0
# SLG_162_b4_v            0
# SLG_162_b5_h            0
# SLG_162_b5_v            0
# SLG_162_b6_h            0
# SLG_162_b6_v            0
# SLG_162_b7_h            0
# SLG_162_b7_v            0
# SLG_162_b8_h            0
# SLG_162_b8_v            1
# SLG_162_b9_h           10
# SLG_162_b9_v           22
# SLG_350_b1_h            0
# SLG_350_b1_v            0
# SLG_350_b2_h            0
# SLG_350_b2_v            0
# SLG_350_b3_h            0
# SLG_350_b3_v            0
# SLG_350_b4_h            0
# SLG_350_b4_v            0
# SLG_350_b5_h            0
# SLG_350_b5_v            0
# SLG_350_b6_h            0
# SLG_350_b6_v            0
# SLG_350_b7_h            0
# SLG_350_b7_v            0
# SLG_350_b8_h            0
# SLG_350_b8_v            1
# SLG_350_b9_h           10
# SLG_350_b9_v           22
# OBS_30_b1_h             0
# OBS_30_b1_v             0
# OBS_30_b2_h             0
# OBS_30_b2_v             0
# OBS_30_b3_h             0
# OBS_30_b3_v             0
# OBS_30_b4_h             0
# OBS_30_b4_v             0
# OBS_30_b5_h             0
# OBS_30_b5_v             0
# OBS_30_b6_h             0
# OBS_30_b6_v             0
# OBS_30_b7_h             0
# OBS_30_b7_v             0
# OBS_30_b8_h             0
# OBS_30_b8_v             1
# OBS_30_b9_h            10
# OBS_30_b9_v            22
# OBS_75_b1_h             0
# OBS_75_b1_v             0
# OBS_75_b2_h             0
# OBS_75_b2_v             0
# OBS_75_b3_h             0
# OBS_75_b3_v             0
# OBS_75_b4_h             0
# OBS_75_b4_v             0
# OBS_75_b5_h             0
# OBS_75_b5_v             0
# OBS_75_b6_h             0
# OBS_75_b6_v             0
# OBS_75_b7_h             0
# OBS_75_b7_v             0
# OBS_75_b8_h             0
# OBS_75_b8_v             1
# OBS_75_b9_h            10
# OBS_75_b9_v            22
# OBS_162_b1_h            0
# OBS_162_b1_v            0
# OBS_162_b2_h            0
# OBS_162_b2_v            0
# OBS_162_b3_h            0
# OBS_162_b3_v            0
# OBS_162_b4_h            0
# OBS_162_b4_v            0
# OBS_162_b5_h            0
# OBS_162_b5_v            0
# OBS_162_b6_h            0
# OBS_162_b6_v            0
# OBS_162_b7_h            0
# OBS_162_b7_v            0
# OBS_162_b8_h            0
# OBS_162_b8_v            1
# OBS_162_b9_h           10
# OBS_162_b9_v           22
# OBS_350_b1_h            0
# OBS_350_b1_v            0
# OBS_350_b2_h            0
# OBS_350_b2_v            0
# OBS_350_b3_h            0
# OBS_350_b3_v            0
# OBS_350_b4_h            0
# OBS_350_b4_v            0
# OBS_350_b5_h            0
# OBS_350_b5_v            0
# OBS_350_b6_h            0
# OBS_350_b6_v            0
# OBS_350_b7_h            0
# OBS_350_b7_v            0
# OBS_350_b8_h            0
# OBS_350_b8_v            1
# OBS_350_b9_h           10
# OBS_350_b9_v           22
# SLGmod_30_b1_h          0
# SLGmod_30_b1_v          0
# SLGmod_30_b2_h          0
# SLGmod_30_b2_v          0
# SLGmod_30_b3_h          0
# SLGmod_30_b3_v          0
# SLGmod_30_b4_h          0
# SLGmod_30_b4_v          0
# SLGmod_30_b5_h          0
# SLGmod_30_b5_v          0
# SLGmod_30_b6_h          0
# SLGmod_30_b6_v          0
# SLGmod_30_b7_h          0
# SLGmod_30_b7_v          0
# SLGmod_30_b8_h          0
# SLGmod_30_b8_v          1
# SLGmod_30_b9_h         10
# SLGmod_30_b9_v         22
# SLGmod_75_b1_h          0
# SLGmod_75_b1_v          0
# SLGmod_75_b2_h          0
# SLGmod_75_b2_v          0
# SLGmod_75_b3_h          0
# SLGmod_75_b3_v          0
# SLGmod_75_b4_h          0
# SLGmod_75_b4_v          0
# SLGmod_75_b5_h          0
# SLGmod_75_b5_v          0
# SLGmod_75_b6_h          0
# SLGmod_75_b6_v          0
# SLGmod_75_b7_h          0
# SLGmod_75_b7_v          0
# SLGmod_75_b8_h          0
# SLGmod_75_b8_v          1
# SLGmod_75_b9_h         10
# SLGmod_75_b9_v         22
# SLGmod_162_b1_h         0
# SLGmod_162_b1_v         0
# SLGmod_162_b2_h         0
# SLGmod_162_b2_v         0
# SLGmod_162_b3_h         0
# SLGmod_162_b3_v         0
# SLGmod_162_b4_h         0
# SLGmod_162_b4_v         0
# SLGmod_162_b5_h         0
# SLGmod_162_b5_v         0
# SLGmod_162_b6_h         0
# SLGmod_162_b6_v         0
# SLGmod_162_b7_h         0
# SLGmod_162_b7_v         0
# SLGmod_162_b8_h         0
# SLGmod_162_b8_v         1
# SLGmod_162_b9_h        10
# SLGmod_162_b9_v        22
# SLGmod_350_b1_h         0
# SLGmod_350_b1_v         0
# SLGmod_350_b2_h         0
# SLGmod_350_b2_v         0
# SLGmod_350_b3_h         0
# SLGmod_350_b3_v         0
# SLGmod_350_b4_h         0
# SLGmod_350_b4_v         0
# SLGmod_350_b5_h         0
# SLGmod_350_b5_v         0
# SLGmod_350_b6_h         0
# SLGmod_350_b6_v         0
# SLGmod_350_b7_h         0
# SLGmod_350_b7_v         0
# SLGmod_350_b8_h         0
# SLGmod_350_b8_v         1
# SLGmod_350_b9_h        10
# SLGmod_350_b9_v        22
# SObat_perc_30_b1_h      0
# SObat_perc_30_b1_v      0
# SObat_perc_30_b2_h      0
# SObat_perc_30_b2_v      0
# SObat_perc_30_b3_h      0
# SObat_perc_30_b3_v      0
# SObat_perc_30_b4_h      0
# SObat_perc_30_b4_v      0
# SObat_perc_30_b5_h      0
# SObat_perc_30_b5_v      0
# SObat_perc_30_b6_h      0
# SObat_perc_30_b6_v      0
# SObat_perc_30_b7_h      0
# SObat_perc_30_b7_v      0
# SObat_perc_30_b8_h      0
# SObat_perc_30_b8_v      1
# SObat_perc_30_b9_h     10
# SObat_perc_30_b9_v     22
# SObat_perc_75_b1_h      0
# SObat_perc_75_b1_v      0
# SObat_perc_75_b2_h      0
# SObat_perc_75_b2_v      0
# SObat_perc_75_b3_h      0
# SObat_perc_75_b3_v      0
# SObat_perc_75_b4_h      0
# SObat_perc_75_b4_v      0
# SObat_perc_75_b5_h      0
# SObat_perc_75_b5_v      0
# SObat_perc_75_b6_h      0
# SObat_perc_75_b6_v      0
# SObat_perc_75_b7_h      0
# SObat_perc_75_b7_v      0
# SObat_perc_75_b8_h      0
# SObat_perc_75_b8_v      1
# SObat_perc_75_b9_h     10
# SObat_perc_75_b9_v     22
# SObat_perc_162_b1_h     0
# SObat_perc_162_b1_v     0
# SObat_perc_162_b2_h     0
# SObat_perc_162_b2_v     0
# SObat_perc_162_b3_h     0
# SObat_perc_162_b3_v     0
# SObat_perc_162_b4_h     0
# SObat_perc_162_b4_v     0
# SObat_perc_162_b5_h     0
# SObat_perc_162_b5_v     0
# SObat_perc_162_b6_h     0
# SObat_perc_162_b6_v     0
# SObat_perc_162_b7_h     0
# SObat_perc_162_b7_v     0
# SObat_perc_162_b8_h     0
# SObat_perc_162_b8_v     1
# SObat_perc_162_b9_h    10
# SObat_perc_162_b9_v    22
# SObat_perc_350_b1_h     0
# SObat_perc_350_b1_v     0
# SObat_perc_350_b2_h     0
# SObat_perc_350_b2_v     0
# SObat_perc_350_b3_h     0
# SObat_perc_350_b3_v     0
# SObat_perc_350_b4_h     0
# SObat_perc_350_b4_v     0
# SObat_perc_350_b5_h     0
# SObat_perc_350_b5_v     0
# SObat_perc_350_b6_h     0
# SObat_perc_350_b6_v     0
# SObat_perc_350_b7_h     0
# SObat_perc_350_b7_v     0
# SObat_perc_350_b8_h     0
# SObat_perc_350_b8_v     1
# SObat_perc_350_b9_h    10
# SObat_perc_350_b9_v    22
# dtype: int64

# %%
newcols89 = [stem+'_'+str(winsize)+'_b'+str(i)+hv   for stem in colstems for winsize in winsizes 
                 for hv in ['_h','_v'] for i in range(8,10)]
for col in newcols89:
    stem=col.split('_')[0].lower()
    df[col].fillna(dd['p'][stem])

# %% [markdown]
# # Create some summary features

# %%
w9 = np.array([0.12541131, 0.12159052, 0.11787189, 0.11434144, 0.11096691,
       0.10772781, 0.10430724, 0.10078822, 0.09699465])
w8 = w9[:-1]/np.sum(w9[:-1])

# %%
for col in ['BATAVG', 'OBP', 'SLG', 'OBS', 'SLGmod','SObat_perc']:
    for winsize in winsizes:
        for hv in ['_h','_v']:
            b_cols9 = [col+'_'+str(winsize)+'_b'+str(i)+hv for i in range(1,10)]
            b_cols8 = [col+'_'+str(winsize)+'_b'+str(i)+hv for i in range(1,9)]
            fcolname9 = 'lineup9_'+col+'_'+str(winsize)+hv
            fcolname8 = 'lineup8_'+col+'_'+str(winsize)+hv
            fcolname9w = 'lineup9_'+col+'_'+str(winsize)+'_w'+hv
            fcolname8w = 'lineup8_'+col+'_'+str(winsize)+'_w'+hv
            df[fcolname9] = np.mean(df.loc[:,b_cols9].to_numpy(),axis=1)
            df[fcolname8] = np.mean(df.loc[:,b_cols8].to_numpy(),axis=1)
            df[fcolname9w] = df.loc[:,b_cols9].to_numpy().dot(w9)
            df[fcolname8w] = df.loc[:,b_cols8].to_numpy().dot(w8)
# Out:
# /tmp/ipykernel_112109/4226624846.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[fcolname8] = np.mean(df.loc[:,b_cols8].to_numpy(),axis=1)
# /tmp/ipykernel_112109/4226624846.py:12: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[fcolname9w] = df.loc[:,b_cols9].to_numpy().dot(w9)
# /tmp/ipykernel_112109/4226624846.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[fcolname8w] = df.loc[:,b_cols8].to_numpy().dot(w8)
# /tmp/ipykernel_112109/4226624846.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[fcolname9] = np.mean(df.loc[:,b_cols9].to_numpy(),axis=1)
# /tmp/ipykernel_112109/4226624846.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[fcolname8] = np.mean(df.loc[:,b_cols8].to_numpy(),axis=1)
# /tmp/ipykernel_112109/4226624846.py:12: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[fcolname9w] = df.loc[:,b_cols9].to_numpy().dot(w9)
# /tmp/ipykernel_112109/4226624846.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[fcolname8w] = df.loc[:,b_cols8].to_numpy().dot(w8)
# /tmp/ipykernel_112109/4226624846.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[fcolname9] = np.mean(df.loc[:,b_cols9].to_numpy(),axis=1)
# /tmp/ipykernel_112109/4226624846.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[fcolname8] = np.mean(df.loc[:,b_cols8].to_numpy(),axis=1)
# /tmp/ipykernel_112109/4226624846.py:12: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[fcolname9w] = df.loc[:,b_cols9].to_numpy().dot(w9)
# /tmp/ipykernel_112109/4226624846.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[fcolname8w] = df.loc[:,b_cols8].to_numpy().dot(w8)
# /tmp/ipykernel_112109/4226624846.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[fcolname9] = np.mean(df.loc[:,b_cols9].to_numpy(),axis=1)
# /tmp/ipykernel_112109/4226624846.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[fcolname8] = np.mean(df.loc[:,b_cols8].to_numpy(),axis=1)
# /tmp/ipykernel_112109/4226624846.py:12: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[fcolname9w] = df.loc[:,b_cols9].to_numpy().dot(w9)
# /tmp/ipykernel_112109/4226624846.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[fcolname8w] = df.loc[:,b_cols8].to_numpy().dot(w8)
# /tmp/ipykernel_112109/4226624846.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[fcolname9] = np.mean(df.loc[:,b_cols9].to_numpy(),axis=1)
# /tmp/ipykernel_112109/4226624846.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[fcolname8] = np.mean(df.loc[:,b_cols8].to_numpy(),axis=1)
# /tmp/ipykernel_112109/4226624846.py:12: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[fcolname9w] = df.loc[:,b_cols9].to_numpy().dot(w9)
# /tmp/ipykernel_112109/4226624846.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[fcolname8w] = df.loc[:,b_cols8].to_numpy().dot(w8)
# /tmp/ipykernel_112109/4226624846.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[fcolname9] = np.mean(df.loc[:,b_cols9].to_numpy(),axis=1)
# /tmp/ipykernel_112109/4226624846.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[fcolname8] = np.mean(df.loc[:,b_cols8].to_numpy(),axis=1)
# /tmp/ipykernel_112109/4226624846.py:12: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[fcolname9w] = df.loc[:,b_cols9].to_numpy().dot(w9)
# /tmp/ipykernel_112109/4226624846.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[fcolname8w] = df.loc[:,b_cols8].to_numpy().dot(w8)
# /tmp/ipykernel_112109/4226624846.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[fcolname9] = np.mean(df.loc[:,b_cols9].to_numpy(),axis=1)
# /tmp/ipykernel_112109/4226624846.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[fcolname8] = np.mean(df.loc[:,b_cols8].to_numpy(),axis=1)
# /tmp/ipykernel_112109/4226624846.py:12: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[fcolname9w] = df.loc[:,b_cols9].to_numpy().dot(w9)
# /tmp/ipykernel_112109/4226624846.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[fcolname8w] = df.loc[:,b_cols8].to_numpy().dot(w8)
# /tmp/ipykernel_112109/4226624846.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[fcolname9] = np.mean(df.loc[:,b_cols9].to_numpy(),axis=1)
# /tmp/ipykernel_112109/4226624846.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[fcolname8] = np.mean(df.loc[:,b_cols8].to_numpy(),axis=1)
# /tmp/ipykernel_112109/4226624846.py:12: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[fcolname9w] = df.loc[:,b_cols9].to_numpy().dot(w9)
# /tmp/ipykernel_112109/4226624846.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[fcolname8w] = df.loc[:,b_cols8].to_numpy().dot(w8)
# /tmp/ipykernel_112109/4226624846.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[fcolname9] = np.mean(df.loc[:,b_cols9].to_numpy(),axis=1)
# /tmp/ipykernel_112109/4226624846.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[fcolname8] = np.mean(df.loc[:,b_cols8].to_numpy(),axis=1)
# /tmp/ipykernel_112109/4226624846.py:12: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[fcolname9w] = df.loc[:,b_cols9].to_numpy().dot(w9)
# /tmp/ipykernel_112109/4226624846.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[fcolname8w] = df.loc[:,b_cols8].to_numpy().dot(w8)
# /tmp/ipykernel_112109/4226624846.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[fcolname9] = np.mean(df.loc[:,b_cols9].to_numpy(),axis=1)
# /tmp/ipykernel_112109/4226624846.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[fcolname8] = np.mean(df.loc[:,b_cols8].to_numpy(),axis=1)
# /tmp/ipykernel_112109/4226624846.py:12: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[fcolname9w] = df.loc[:,b_cols9].to_numpy().dot(w9)
# /tmp/ipykernel_112109/4226624846.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[fcolname8w] = df.loc[:,b_cols8].to_numpy().dot(w8)
# /tmp/ipykernel_112109/4226624846.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[fcolname9] = np.mean(df.loc[:,b_cols9].to_numpy(),axis=1)
# /tmp/ipykernel_112109/4226624846.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[fcolname8] = np.mean(df.loc[:,b_cols8].to_numpy(),axis=1)
# /tmp/ipykernel_112109/4226624846.py:12: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[fcolname9w] = df.loc[:,b_cols9].to_numpy().dot(w9)
# /tmp/ipykernel_112109/4226624846.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[fcolname8w] = df.loc[:,b_cols8].to_numpy().dot(w8)
# /tmp/ipykernel_112109/4226624846.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[fcolname9] = np.mean(df.loc[:,b_cols9].to_numpy(),axis=1)
# /tmp/ipykernel_112109/4226624846.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[fcolname8] = np.mean(df.loc[:,b_cols8].to_numpy(),axis=1)
# /tmp/ipykernel_112109/4226624846.py:12: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[fcolname9w] = df.loc[:,b_cols9].to_numpy().dot(w9)
# /tmp/ipykernel_112109/4226624846.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[fcolname8w] = df.loc[:,b_cols8].to_numpy().dot(w8)
# /tmp/ipykernel_112109/4226624846.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[fcolname9] = np.mean(df.loc[:,b_cols9].to_numpy(),axis=1)
# /tmp/ipykernel_112109/4226624846.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[fcolname8] = np.mean(df.loc[:,b_cols8].to_numpy(),axis=1)
# /tmp/ipykernel_112109/4226624846.py:12: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[fcolname9w] = df.loc[:,b_cols9].to_numpy().dot(w9)
# /tmp/ipykernel_112109/4226624846.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[fcolname8w] = df.loc[:,b_cols8].to_numpy().dot(w8)
# /tmp/ipykernel_112109/4226624846.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[fcolname9] = np.mean(df.loc[:,b_cols9].to_numpy(),axis=1)
# /tmp/ipykernel_112109/4226624846.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[fcolname8] = np.mean(df.loc[:,b_cols8].to_numpy(),axis=1)
# /tmp/ipykernel_112109/4226624846.py:12: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[fcolname9w] = df.loc[:,b_cols9].to_numpy().dot(w9)
# /tmp/ipykernel_112109/4226624846.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[fcolname8w] = df.loc[:,b_cols8].to_numpy().dot(w8)
# /tmp/ipykernel_112109/4226624846.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[fcolname9] = np.mean(df.loc[:,b_cols9].to_numpy(),axis=1)
# /tmp/ipykernel_112109/4226624846.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[fcolname8] = np.mean(df.loc[:,b_cols8].to_numpy(),axis=1)
# /tmp/ipykernel_112109/4226624846.py:12: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[fcolname9w] = df.loc[:,b_cols9].to_numpy().dot(w9)
# /tmp/ipykernel_112109/4226624846.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[fcolname8w] = df.loc[:,b_cols8].to_numpy().dot(w8)
# /tmp/ipykernel_112109/4226624846.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[fcolname9] = np.mean(df.loc[:,b_cols9].to_numpy(),axis=1)
# /tmp/ipykernel_112109/4226624846.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[fcolname8] = np.mean(df.loc[:,b_cols8].to_numpy(),axis=1)
# /tmp/ipykernel_112109/4226624846.py:12: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[fcolname9w] = df.loc[:,b_cols9].to_numpy().dot(w9)
# /tmp/ipykernel_112109/4226624846.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[fcolname8w] = df.loc[:,b_cols8].to_numpy().dot(w8)
# /tmp/ipykernel_112109/4226624846.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[fcolname9] = np.mean(df.loc[:,b_cols9].to_numpy(),axis=1)
# /tmp/ipykernel_112109/4226624846.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[fcolname8] = np.mean(df.loc[:,b_cols8].to_numpy(),axis=1)
# /tmp/ipykernel_112109/4226624846.py:12: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[fcolname9w] = df.loc[:,b_cols9].to_numpy().dot(w9)
# /tmp/ipykernel_112109/4226624846.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[fcolname8w] = df.loc[:,b_cols8].to_numpy().dot(w8)
# /tmp/ipykernel_112109/4226624846.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[fcolname9] = np.mean(df.loc[:,b_cols9].to_numpy(),axis=1)
# /tmp/ipykernel_112109/4226624846.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[fcolname8] = np.mean(df.loc[:,b_cols8].to_numpy(),axis=1)
# /tmp/ipykernel_112109/4226624846.py:12: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[fcolname9w] = df.loc[:,b_cols9].to_numpy().dot(w9)
# /tmp/ipykernel_112109/4226624846.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[fcolname8w] = df.loc[:,b_cols8].to_numpy().dot(w8)
# /tmp/ipykernel_112109/4226624846.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[fcolname9] = np.mean(df.loc[:,b_cols9].to_numpy(),axis=1)
# /tmp/ipykernel_112109/4226624846.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[fcolname8] = np.mean(df.loc[:,b_cols8].to_numpy(),axis=1)
# /tmp/ipykernel_112109/4226624846.py:12: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[fcolname9w] = df.loc[:,b_cols9].to_numpy().dot(w9)
# /tmp/ipykernel_112109/4226624846.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[fcolname8w] = df.loc[:,b_cols8].to_numpy().dot(w8)
# /tmp/ipykernel_112109/4226624846.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[fcolname9] = np.mean(df.loc[:,b_cols9].to_numpy(),axis=1)
# /tmp/ipykernel_112109/4226624846.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[fcolname8] = np.mean(df.loc[:,b_cols8].to_numpy(),axis=1)
# /tmp/ipykernel_112109/4226624846.py:12: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[fcolname9w] = df.loc[:,b_cols9].to_numpy().dot(w9)
# /tmp/ipykernel_112109/4226624846.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[fcolname8w] = df.loc[:,b_cols8].to_numpy().dot(w8)
# /tmp/ipykernel_112109/4226624846.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[fcolname9] = np.mean(df.loc[:,b_cols9].to_numpy(),axis=1)
# /tmp/ipykernel_112109/4226624846.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[fcolname8] = np.mean(df.loc[:,b_cols8].to_numpy(),axis=1)
# /tmp/ipykernel_112109/4226624846.py:12: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[fcolname9w] = df.loc[:,b_cols9].to_numpy().dot(w9)
# /tmp/ipykernel_112109/4226624846.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[fcolname8w] = df.loc[:,b_cols8].to_numpy().dot(w8)
# /tmp/ipykernel_112109/4226624846.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[fcolname9] = np.mean(df.loc[:,b_cols9].to_numpy(),axis=1)
# /tmp/ipykernel_112109/4226624846.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[fcolname8] = np.mean(df.loc[:,b_cols8].to_numpy(),axis=1)
# /tmp/ipykernel_112109/4226624846.py:12: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[fcolname9w] = df.loc[:,b_cols9].to_numpy().dot(w9)
# /tmp/ipykernel_112109/4226624846.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[fcolname8w] = df.loc[:,b_cols8].to_numpy().dot(w8)
# /tmp/ipykernel_112109/4226624846.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[fcolname9] = np.mean(df.loc[:,b_cols9].to_numpy(),axis=1)
# /tmp/ipykernel_112109/4226624846.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[fcolname8] = np.mean(df.loc[:,b_cols8].to_numpy(),axis=1)
# /tmp/ipykernel_112109/4226624846.py:12: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[fcolname9w] = df.loc[:,b_cols9].to_numpy().dot(w9)
# /tmp/ipykernel_112109/4226624846.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[fcolname8w] = df.loc[:,b_cols8].to_numpy().dot(w8)
# /tmp/ipykernel_112109/4226624846.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[fcolname9] = np.mean(df.loc[:,b_cols9].to_numpy(),axis=1)
# /tmp/ipykernel_112109/4226624846.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[fcolname8] = np.mean(df.loc[:,b_cols8].to_numpy(),axis=1)
# /tmp/ipykernel_112109/4226624846.py:12: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[fcolname9w] = df.loc[:,b_cols9].to_numpy().dot(w9)
# /tmp/ipykernel_112109/4226624846.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[fcolname8w] = df.loc[:,b_cols8].to_numpy().dot(w8)

# %%
df.to_csv('Data/df_bp9.csv', index=False)
